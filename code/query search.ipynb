# %%
import pickle
import sqlite3

# %%
database_path=r"C:\Users\saurav\Desktop\HCL final\NLP-Search-Engine-COVID-19-Dataset-main\covid19.db"
parsed_parameter_save_path='C:/Users/saurav/Desktop/HCL final/NLP-Search-Engine-COVID-19-Dataset-main/parsed_parameters.pickle'
print_sql_queries=True

# %%
with open(parsed_parameter_save_path, 'rb') as f:
    queries, state_country_dict, place_lower_to_normal=pickle.load(f)
# queries

# %%
con = sqlite3.connect(database_path)

# %%
case_type_dict={
    'confirm': 'Confirmed',
    'recover': 'Recovered',
    'death': 'Deaths',
    'increase rate': 'Increase_rate',
    'active': 'Active'
}

func_type_dict={
    'maximum': 'MAX',
    'minimum': 'MIN',
    'average': 'AVG',
    'sum': ''
}

# %%
def is_us_state(state):
    if state_country_dict[state]=='us':
        return True
    return False

# def extra_result(table, state, time, country, print_sql):
#     print("Other Details:")
#     if table=='us':


def generate_case_query_result(query,print_sql):
    case_type=case_type_dict[query['Case Type']]
    func_type=func_type_dict[query['Function Type']]
    time=query['Time Duration']

    if query['Place']['states']:
        state=place_lower_to_normal[query['Place']['states'][0]]
        if is_us_state(query['Place']['states'][0]):
            if case_type == 'Active' or case_type == 'Recovered' or case_type == 'Increase_rate':
                # print(case_type+" Data is not provided for this State. Other related information about "+state+" is given below:")
                print(case_type+" Data is not provided for this State.")
                # extra_result(table='us',state=state,time=time,country='us',print_sql=print_sql)
                return

            else:
                if func_type=='':
                    # sql = "SELECT "+case_type+" FROM us WHERE Province_State = '"+state+ "' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"';"
                    sql = "SELECT SUM("+case_type+") FROM us WHERE Province_State = '"+state+ "' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Province_State;"
                    if print_sql:
                        print(sql)
                    cur = con.execute(sql)
                    a = cur.fetchall()
                    ans = a[-1][0]-a[0][0]
                    print(ans)
                    return

                else:
                    sql="SELECT "+func_type+"(sum) from"+"(SELECT SUM("+case_type+") as sum FROM us WHERE Province_State = '"+state+ "' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Province_State);"
                    if print_sql:
                        print(sql)
                    cur = con.execute(sql)
                    ans = cur.fetchone()
                    print(ans[0])
                    return
        
        else:
            if case_type == 'Increase_rate':
                # print(case_type+" Data is not provided for this State. Other related information about "+state+" is given below:")
                # extra_result(table='timeseries', state=state,time=time,country=state_country_dict[query['Place']['states'][0]],print_sql=print_sql)
                print(case_type+" Data is not provided for this State.")
                return
            
            elif case_type == 'Active':
                case_type = "Confirmed-Recovered-Deaths"
            
            if func_type=='':
                sql="SELECT "+case_type+" FROM timeseries WHERE Province_State = '"+state+ "' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"';"
                if print_sql:
                    print(sql)
                cur = con.execute(sql)
                a = cur.fetchall()
                ans = a[-1][0]-a[0][0]
                print(ans)
                return

            else:
                sql="SELECT "+func_type+"("+case_type+") FROM timeseries WHERE Province_State = '"+state+ "' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"';"
                if print_sql:
                    print(sql)
                cur = con.execute(sql)
                ans = cur.fetchone()
                print(ans[0])
                return

    elif query['Place']['countries']:
        country=place_lower_to_normal[query['Place']['countries'][0]]
        if case_type == 'Increase_rate':
            # print(case_type+" Data is not provided for this Country. Other related information about "+country+" is given below:")
            # extra_result(table='countries_aggregated', state=None,time=time,country=country,print_sql=print_sql)
            print(case_type+" Data is not provided for "+country+".")
            return
        
        elif case_type == 'Active':
            case_type = "Confirmed-Recovered-Deaths"
        
        if func_type=='':
            sql="SELECT "+case_type+" FROM countries_aggregated WHERE Country = '"+country+ "' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"';"
            if print_sql:
                print(sql)
            cur = con.execute(sql)
            a = cur.fetchall()
            ans = a[-1][0]-a[0][0]
            print(ans)
            return

        else:
            sql="SELECT "+func_type+"("+case_type+") FROM countries_aggregated WHERE Country = '"+country+ "' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"';"
            if print_sql:
                print(sql)
            cur = con.execute(sql)
            ans = cur.fetchone()
            print(ans[0])
            return
    
    else:
        if case_type == 'Active':
            case_type = "Confirmed-Recovered-Deaths"
        
        if case_type == 'Increase_rate':
            time['begin']=max(time['begin'],'2020-01-23')
        
        if func_type=='':
            sql="SELECT "+case_type+" FROM worldwide_aggregate WHERE Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"';"
            if print_sql:
                print(sql)
            cur = con.execute(sql)
            a = cur.fetchall()
            ans = a[-1][0]-a[0][0]
            print(ans)
            return

        else:
            sql="SELECT "+func_type+"("+case_type+") FROM worldwide_aggregate WHERE Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"';"
            if print_sql:
                print(sql)
            cur = con.execute(sql)
            ans = cur.fetchone()
            print(ans[0])
            return

def generate_place_query_result(query,print_sql):
    case_type=case_type_dict[query['Case Type']]
    func_type=func_type_dict[query['Function Type']]
    time=query['Time Duration']

    if query['Operation Type']=='country' and query['Place']['countries']:
        query['Operation Type']='state'
    
    if query['Operation Type']=='state':
        if query['Place']['countries']:
            if 'us' in query['Place']['countries']:
                if case_type == 'Active' or case_type == 'Recovered' or case_type == 'Increase_rate':
                    # print(case_type+" Data is not provided for US. Other related information about US is given below:")
                    # extra_result(table='countries_aggregated',state=None,time=time,country='us',print_sql=print_sql)
                    print(case_type+" Data is not provided for US.")
                    return

                else:
                    if func_type=='':
                        func_type='MAX'

                    sql = "SELECT Province_State FROM (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM("+case_type+") as sum FROM us WHERE Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Province_State) GROUP BY Province_State) WHERE cases = (SELECT "+func_type+"(cases) from (SELECT (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM("+case_type+") as sum FROM us WHERE Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Province_State) GROUP BY Province_State));"
                    
                    if print_sql:
                        print(sql)
                    cur = con.execute(sql)
                    ans = cur.fetchone()
                    print(ans[0])
                    return
            else:
                if case_type == 'Increase_rate':
                    country=place_lower_to_normal[query['Place']['countries'][0]] 
                    # print(case_type+" Data is not provided for"+country+". Other related information about "+country+" is given below:")
                    # extra_result(table='countries_aggregated',state=None,time=time,country=query['Place']['countries'][0],print_sql=print_sql)
                    print(case_type+" Data is not provided for "+country+".")
                    return

                else:
                    if func_type=='':
                        func_type='MAX'
                    
                    if case_type == 'Active':
                        case_type = "Confirmed-Recovered-Deaths"
                    
                    country=place_lower_to_normal[query['Place']['countries'][0]] 
                    sql = "SELECT Province_State FROM (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM("+case_type+") as sum FROM timeseries WHERE Country_Region = '"+country+"' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Province_State) GROUP BY Province_State) WHERE cases = (SELECT "+func_type+"(cases) from (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM("+case_type+") as sum FROM timeseries WHERE Country_Region = '"+country+"' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Province_State) GROUP BY Province_State));"
                    
                    if print_sql:
                        print(sql)
                    cur = con.execute(sql)
                    ans = cur.fetchone()
                    print(ans[0])
                    return
        else:
            if case_type == 'Increase_rate':
                # print(case_type+" Data is not provided for States. Other related information about world is given below:")
                # extra_result(table='worldwide_aggregate',state=None,time=time,country=None,print_sql=print_sql)
                print(case_type+" Data is not provided for States.")
                return

            else:
                if func_type=='':
                    func_type='MAX'
                
                if case_type == 'Active':
                    case_type = "Confirmed-Recovered-Deaths"
                
                sql = "SELECT Province_State FROM (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM("+case_type+") as sum FROM timeseries WHERE Province_State <> '' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Province_State) GROUP BY Province_State) WHERE cases = (SELECT "+func_type+"(cases) from (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM("+case_type+") as sum FROM timeseries WHERE Province_State <> '' AND Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Province_State) GROUP BY Province_State));"
                
                if print_sql:
                    print(sql)
                cur = con.execute(sql)
                ans = cur.fetchone()
                print(ans[0])
                return
    elif query['Operation Type']=='country':
        if case_type == 'Increase_rate':
            # print(case_type+" Data is not provided for Countries. Other related information about World is given below:")
            # extra_result(table='worldwide_aggregate',state=None,time=time,country=None,print_sql=print_sql)
            print(case_type+" Data is not provided for Countries.")
            return

        else:
            if func_type=='':
                func_type='MAX'
            
            if case_type == 'Active':
                case_type = "Confirmed-Recovered-Deaths"
            
            sql = "SELECT Country FROM (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM("+case_type+") as sum FROM countries_aggregated WHERE Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Country) GROUP BY Country) WHERE cases = (SELECT "+func_type+"(cases) from (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM("+case_type+") as sum FROM countries_aggregated WHERE Date BETWEEN '"+time['begin']+"' AND '"+time['end']+"' GROUP BY Date, Country) GROUP BY Country));"
            
            if print_sql:
                print(sql)
            cur = con.execute(sql)
            ans = cur.fetchone()
            print(ans[0])
            return

def generate_result(query, print_sql):
    if query['Operation Type']=='cases':
        generate_case_query_result(query,print_sql)
        if query['Place']['no_match']:
            print("No result found for: ", query['Place']['no_match'])
    else:
        generate_place_query_result(query,print_sql)

# %%
i=0
for query in queries:
    print(i)
    i=i+1
    print(query['query'])
    generate_result(query,print_sql_queries)
    print()
# Out:
# 0
# total number of cases found in Afganistan?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-01-01' AND '2020-12-31';
# 76822931
# No result found for:  ['afganistan']
#
# 1
# total number of cases found in Colombia till july?
# SELECT Confirmed FROM countries_aggregated WHERE Country = 'Colombia' AND Date BETWEEN '2020-07-01' AND '2020-07-31';
# 193499
#
# 2
# total number of new cases found in France in april?
# SELECT Confirmed FROM countries_aggregated WHERE Country = 'France' AND Date BETWEEN '2020-04-01' AND '2020-04-31';
# 111739
#
# 3
# total number of new cases found in Greece between april to september?
# SELECT Confirmed FROM countries_aggregated WHERE Country = 'Greece' AND Date BETWEEN '2020-04-01' AND '2020-09-31';
# 17060
#
# 4
# total number cases recovered in Hungary?
# SELECT Recovered FROM countries_aggregated WHERE Country = 'Hungary' AND Date BETWEEN '2020-01-01' AND '2020-12-31';
# 97443
#
# 5
# total number of cases recovered in Iceland till may?
# SELECT Recovered FROM countries_aggregated WHERE Country = 'Iceland' AND Date BETWEEN '2020-05-01' AND '2020-05-31';
# 105
#
# 6
# total number of new cases recovered in Indonesia in may?
# SELECT Recovered FROM countries_aggregated WHERE Country = 'Indonesia' AND Date BETWEEN '2020-05-01' AND '2020-05-31';
# 5717
#
# 7
# total number of new cases recovered in india from march to december?
# SELECT Recovered FROM countries_aggregated WHERE Country = 'India' AND Date BETWEEN '2020-03-01' AND '2020-12-31';
# 9606108
#
# 8
# total number of deaths in india?
# SELECT Deaths FROM countries_aggregated WHERE Country = 'India' AND Date BETWEEN '2020-01-01' AND '2020-12-31';
# 145810
#
# 9
# total number of deaths in china till august?
# SELECT Deaths FROM countries_aggregated WHERE Country = 'China' AND Date BETWEEN '2020-08-01' AND '2020-08-31';
# 56
#
# 10
# total number of deaths in US in august?
# SELECT Deaths FROM countries_aggregated WHERE Country = 'US' AND Date BETWEEN '2020-08-01' AND '2020-08-31';
# 28433
#
# 11
# total number of deaths in poland between august and december?
# SELECT Deaths FROM countries_aggregated WHERE Country = 'Poland' AND Date BETWEEN '2020-08-01' AND '2020-12-31';
# 23676
#
# 12
# total number of cases found in world?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-01-01' AND '2020-12-31';
# 76822931
#
# 13
# total number of cases found in world till july?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-07-01' AND '2020-07-31';
# 6928044
#
# 14
# total number of new cases found in world in april?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-04-01' AND '2020-04-31';
# 2322964
#
# 15
# total number of new cases found in world between april to september?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-04-01' AND '2020-09-31';
# 33044150
#
# 16
# total number cases recovred in world?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-01-01' AND '2020-12-31';
# 76822931
#
# 17
# total number of cases recovred in world till may?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-01-01' AND '2020-12-31';
# 76822931
#
# 18
# total number of new cases recovred in world in may?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-05-01' AND '2020-05-31';
# 2821851
#
# 19
# total number of new cases recovred in world from march to december?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-03-01' AND '2020-12-31';
# 76735092
#
# 20
# total number of deaths in world?
# SELECT Deaths FROM worldwide_aggregate WHERE Date BETWEEN '2020-01-01' AND '2020-12-31';
# 1693188
#
# 21
# total number of deaths in world till august?
# SELECT Deaths FROM worldwide_aggregate WHERE Date BETWEEN '2020-08-01' AND '2020-08-31';
# 169962
#
# 22
# total number of deaths in world in august?
# SELECT Deaths FROM worldwide_aggregate WHERE Date BETWEEN '2020-08-01' AND '2020-08-31';
# 169962
#
# 23
# total number of deaths in world between august and december?
# SELECT Deaths FROM worldwide_aggregate WHERE Date BETWEEN '2020-08-01' AND '2020-12-31';
# 1012105
#
# 24
# In which month maximum number of cases were found in world?
# SELECT MAX(Confirmed) FROM worldwide_aggregate WHERE Date BETWEEN '2020-01-01' AND '2020-12-31';
# 76823486
#
# 25
# what is the maximum increase rate found till between july to decemer?
# SELECT MAX(Increase_rate) FROM worldwide_aggregate WHERE Date BETWEEN '2020-07-01' AND '2020-07-31';
# 2.0827246014729046
#
# 26
# In which month maximum number of cases were recovered in world?
# SELECT MAX(Recovered) FROM worldwide_aggregate WHERE Date BETWEEN '2020-01-01' AND '2020-12-31';
# 47249332
#
# 27
# In which month maximum number of deaths were found in world?
# SELECT MAX(Deaths) FROM worldwide_aggregate WHERE Date BETWEEN '2020-01-01' AND '2020-12-31';
# 1693205
#
# 28
# country having maximum number of deaths?
# SELECT Country FROM (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Deaths) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Country) GROUP BY Country) WHERE cases = (SELECT MAX(cases) from (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Deaths) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Country) GROUP BY Country));
# US
#
# 29
# country having maximum number of deaths till june?
# SELECT Country FROM (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Deaths) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-06-01' AND '2020-06-31' GROUP BY Date, Country) GROUP BY Country) WHERE cases = (SELECT MAX(cases) from (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Deaths) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-06-01' AND '2020-06-31' GROUP BY Date, Country) GROUP BY Country));
# Brazil
#
# 30
# country having maximum number of recovery cases?
# SELECT Country FROM (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Recovered) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Country) GROUP BY Country) WHERE cases = (SELECT MAX(cases) from (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Recovered) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Country) GROUP BY Country));
# India
#
# 31
# country having maximum number of recovery cases till july?
# SELECT Country FROM (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Recovered) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-07-01' AND '2020-07-31' GROUP BY Date, Country) GROUP BY Country) WHERE cases = (SELECT MAX(cases) from (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Recovered) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-07-01' AND '2020-07-31' GROUP BY Date, Country) GROUP BY Country));
# Brazil
#
# 32
# country having maximum number of cases?
# SELECT Country FROM (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Confirmed) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Country) GROUP BY Country) WHERE cases = (SELECT MAX(cases) from (SELECT Country, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Country, SUM(Confirmed) as sum FROM countries_aggregated WHERE Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Country) GROUP BY Country));
# US
#
# 33
# state having maximum number of cases till september in US?
# SELECT Province_State FROM (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Confirmed) as sum FROM us WHERE Date BETWEEN '2020-09-01' AND '2020-09-31' GROUP BY Date, Province_State) GROUP BY Province_State) WHERE cases = (SELECT MAX(cases) from (SELECT (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Confirmed) as sum FROM us WHERE Date BETWEEN '2020-09-01' AND '2020-09-31' GROUP BY Date, Province_State) GROUP BY Province_State));
# Texas
#
# 34
# state having maximum number of deaths in US?
# SELECT Province_State FROM (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Deaths) as sum FROM us WHERE Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Province_State) GROUP BY Province_State) WHERE cases = (SELECT MAX(cases) from (SELECT (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Deaths) as sum FROM us WHERE Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Province_State) GROUP BY Province_State));
# New York
#
# 35
# state having maximum number of deaths till june in Australia?
# SELECT Province_State FROM (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Deaths) as sum FROM timeseries WHERE Country_Region = 'Australia' AND Date BETWEEN '2020-06-01' AND '2020-06-31' GROUP BY Date, Province_State) GROUP BY Province_State) WHERE cases = (SELECT MAX(cases) from (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Deaths) as sum FROM timeseries WHERE Country_Region = 'Australia' AND Date BETWEEN '2020-06-01' AND '2020-06-31' GROUP BY Date, Province_State) GROUP BY Province_State));
# New South Wales
#
# 36
# state having maximum number of recovery cases in US?
# Recovered Data is not provided for US.
#
# 37
# state having maximum number of recovery cases till july in Canada?
# SELECT Province_State FROM (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Recovered) as sum FROM timeseries WHERE Country_Region = 'Canada' AND Date BETWEEN '2020-07-01' AND '2020-07-31' GROUP BY Date, Province_State) GROUP BY Province_State) WHERE cases = (SELECT MAX(cases) from (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Recovered) as sum FROM timeseries WHERE Country_Region = 'Canada' AND Date BETWEEN '2020-07-01' AND '2020-07-31' GROUP BY Date, Province_State) GROUP BY Province_State));
# Alberta
#
# 38
# state having maximum number of cases in China?
# SELECT Province_State FROM (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Confirmed) as sum FROM timeseries WHERE Country_Region = 'China' AND Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Province_State) GROUP BY Province_State) WHERE cases = (SELECT MAX(cases) from (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Confirmed) as sum FROM timeseries WHERE Country_Region = 'China' AND Date BETWEEN '2020-01-01' AND '2020-12-31' GROUP BY Date, Province_State) GROUP BY Province_State));
# Hubei
#
# 39
# state having maximum number of cases till september in Netherlands?
# SELECT Province_State FROM (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Confirmed) as sum FROM timeseries WHERE Country_Region = 'Netherlands' AND Date BETWEEN '2020-09-01' AND '2020-09-31' GROUP BY Date, Province_State) GROUP BY Province_State) WHERE cases = (SELECT MAX(cases) from (SELECT Province_State, (MAX(sum)-MIN(sum)) as cases FROM (SELECT Date, Province_State, SUM(Confirmed) as sum FROM timeseries WHERE Country_Region = 'Netherlands' AND Date BETWEEN '2020-09-01' AND '2020-09-31' GROUP BY Date, Province_State) GROUP BY Province_State));
#
#
# 40
# what are the total number of covid cases found in the world till september?
# SELECT Confirmed FROM worldwide_aggregate WHERE Date BETWEEN '2020-09-01' AND '2020-09-31';
# 8232102
#
# 41
# what is the maximum increase rate found till now?
# SELECT MAX(Increase_rate) FROM worldwide_aggregate WHERE Date BETWEEN '2020-01-23' AND '2020-12-31';
# 90.570550051247

# %%
con.close()
